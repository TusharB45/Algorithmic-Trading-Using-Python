# %%
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns
sns.set
# Out:
# <function seaborn.rcmod.set(*args, **kwargs)>

# %%
df = pd.read_csv('C:/Users/Neha Borse/OneDrive/Desktop/New folder (2)/data science/Projects/Data science project\Calculate historical stock returns for a stock of your choice/FB.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 2474  2022-03-18  206.699997  216.800003  206.000000  216.490005  216.490005
# 2475  2022-03-21  214.500000  214.710007  207.630005  211.490005  211.490005
# 2476  2022-03-22  211.369995  219.460007  210.179993  216.649994  216.649994
# 2477  2022-03-23  213.330002  216.800003  212.160004  213.460007  213.460007
# 2478  2022-03-24  215.000000  220.669998  214.789993  219.570007  219.570007
#
# ...

# %%
df = df[['Date', 'Adj Close']]

# %%
df.head
# Out:
# <bound method NDFrame.head of             Date   Adj Close
# 0     2012-05-18   38.230000
# 1     2012-05-21   34.029999
# 2     2012-05-22   31.000000
# 3     2012-05-23   32.000000
# 4     2012-05-24   33.029999
# ...          ...         ...
# 2474  2022-03-18  216.490005
# 2475  2022-03-21  211.490005
# 2476  2022-03-22  216.649994
# 2477  2022-03-23  213.460007
# 2478  2022-03-24  219.570007
#
# [2479 rows x 2 columns]>

# %%
df.rename(columns={'Date' : 'date', 'Adj Close': 'price_t'}, inplace=True)
# Out:
# C:\Users\Neha Borse\AppData\Local\Temp\ipykernel_22620\1614151163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Date' : 'date', 'Adj Close': 'price_t'}, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of             date     price_t
# 0     2012-05-18   38.230000
# 1     2012-05-21   34.029999
# 2     2012-05-22   31.000000
# 3     2012-05-23   32.000000
# 4     2012-05-24   33.029999
# ...          ...         ...
# 2474  2022-03-18  216.490005
# 2475  2022-03-21  211.490005
# 2476  2022-03-22  216.649994
# 2477  2022-03-23  213.460007
# 2478  2022-03-24  219.570007
#
# [2479 rows x 2 columns]>

# %%
df['price_t-1'] = df['price_t'].shift(1)
# Out:
# C:\Users\Neha Borse\AppData\Local\Temp\ipykernel_22620\773487150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_t-1'] = df['price_t'].shift(1)

# %%
df
# Out:
#             date     price_t   price_t-1
# 0     2012-05-18   38.230000         NaN
# 1     2012-05-21   34.029999   38.230000
# 2     2012-05-22   31.000000   34.029999
# 3     2012-05-23   32.000000   31.000000
# 4     2012-05-24   33.029999   32.000000
# ...          ...         ...         ...
# 2474  2022-03-18  216.490005  207.839996
# 2475  2022-03-21  211.490005  216.490005
# 2476  2022-03-22  216.649994  211.490005
# 2477  2022-03-23  213.460007  216.649994
# 2478  2022-03-24  219.570007  213.460007
#
# [2479 rows x 3 columns]

# %%
df['returns_manual'] = (df['price_t'] / df['price_t-1']) - 1
# Out:
# C:\Users\Neha Borse\AppData\Local\Temp\ipykernel_22620\3992734040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['returns_manual'] = (df['price_t'] / df['price_t-1']) - 1

# %%
df
# Out:
#             date     price_t   price_t-1  returns_manual
# 0     2012-05-18   38.230000         NaN             NaN
# 1     2012-05-21   34.029999   38.230000       -0.109861
# 2     2012-05-22   31.000000   34.029999       -0.089039
# 3     2012-05-23   32.000000   31.000000        0.032258
# 4     2012-05-24   33.029999   32.000000        0.032187
# ...          ...         ...         ...             ...
# 2474  2022-03-18  216.490005  207.839996        0.041619
# 2475  2022-03-21  211.490005  216.490005       -0.023096
# 2476  2022-03-22  216.649994  211.490005        0.024398
# 2477  2022-03-23  213.460007  216.649994       -0.014724
# 2478  2022-03-24  219.570007  213.460007        0.028624
#
# [2479 rows x 4 columns]

# %%
df['return_pct_change_method'] = df['price_t'].pct_change(1)
# Out:
# C:\Users\Neha Borse\AppData\Local\Temp\ipykernel_22620\1280457077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['return_pct_change_method'] = df['price_t'].pct_change(1)

# %%
df
# Out:
#             date     price_t   price_t-1  returns_manual  \
# 0     2012-05-18   38.230000         NaN             NaN
# 1     2012-05-21   34.029999   38.230000       -0.109861
# 2     2012-05-22   31.000000   34.029999       -0.089039
# 3     2012-05-23   32.000000   31.000000        0.032258
# 4     2012-05-24   33.029999   32.000000        0.032187
# ...          ...         ...         ...             ...
# 2474  2022-03-18  216.490005  207.839996        0.041619
# 2475  2022-03-21  211.490005  216.490005       -0.023096
# 2476  2022-03-22  216.649994  211.490005        0.024398
# 2477  2022-03-23  213.460007  216.649994       -0.014724
# 2478  2022-03-24  219.570007  213.460007        0.028624
#
#       return_pct_change_method
# 0                          NaN
# 1                    -0.109861
# 2                    -0.089039
# 3                     0.032258
# 4                     0.032187
# ...                        ...
# 2474                  0.041619
# ...

# %%
df.set_index('date', inplace=True)

# %%
df
# Out:
#                price_t   price_t-1  returns_manual  return_pct_change_method
# date
# 2012-05-18   38.230000         NaN             NaN                       NaN
# 2012-05-21   34.029999   38.230000       -0.109861                 -0.109861
# 2012-05-22   31.000000   34.029999       -0.089039                 -0.089039
# 2012-05-23   32.000000   31.000000        0.032258                  0.032258
# 2012-05-24   33.029999   32.000000        0.032187                  0.032187
# ...                ...         ...             ...                       ...
# 2022-03-18  216.490005  207.839996        0.041619                  0.041619
# 2022-03-21  211.490005  216.490005       -0.023096                 -0.023096
# 2022-03-22  216.649994  211.490005        0.024398                  0.024398
# 2022-03-23  213.460007  216.649994       -0.014724                 -0.014724
# 2022-03-24  219.570007  213.460007        0.028624                  0.028624
#
# [2479 rows x 4 columns]

# %%
df['price_t'].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='date'>

# %%
df['returns_manual'].plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='date'>

# %%
import numpy as np
average_return = np.mean(df['returns_manual'])
std_deviation = np.std(df['returns_manual'])

# %%
df.drop('average_return', axis=1)
# Out:
#                price_t   price_t-1  returns_manual  return_pct_change_method  \
# date
# 2012-05-18   38.230000         NaN             NaN                       NaN
# 2012-05-21   34.029999   38.230000       -0.109861                 -0.109861
# 2012-05-22   31.000000   34.029999       -0.089039                 -0.089039
# 2012-05-23   32.000000   31.000000        0.032258                  0.032258
# 2012-05-24   33.029999   32.000000        0.032187                  0.032187
# ...                ...         ...             ...                       ...
# 2022-03-18  216.490005  207.839996        0.041619                  0.041619
# 2022-03-21  211.490005  216.490005       -0.023096                 -0.023096
# 2022-03-22  216.649994  211.490005        0.024398                  0.024398
# 2022-03-23  213.460007  216.649994       -0.014724                 -0.014724
# 2022-03-24  219.570007  213.460007        0.028624                  0.028624
#
#             std_deviation
# date
# ...

# %%
df
# Out:
#                price_t   price_t-1  returns_manual  return_pct_change_method  \
# date
# 2012-05-18   38.230000         NaN             NaN                       NaN
# 2012-05-21   34.029999   38.230000       -0.109861                 -0.109861
# 2012-05-22   31.000000   34.029999       -0.089039                 -0.089039
# 2012-05-23   32.000000   31.000000        0.032258                  0.032258
# 2012-05-24   33.029999   32.000000        0.032187                  0.032187
# ...                ...         ...             ...                       ...
# 2022-03-18  216.490005  207.839996        0.041619                  0.041619
# 2022-03-21  211.490005  216.490005       -0.023096                 -0.023096
# 2022-03-22  216.649994  211.490005        0.024398                  0.024398
# 2022-03-23  213.460007  216.649994       -0.014724                 -0.014724
# 2022-03-24  219.570007  213.460007        0.028624                  0.028624
#
# ...
